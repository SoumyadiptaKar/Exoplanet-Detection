# %% [markdown]
# #Setup

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
from keras.models import Model
from keras.layers import Input, Dense, LSTM, concatenate, Activation, MaxPool1D, Flatten
from keras.layers import Conv1D, BatchNormalization, GlobalAveragePooling1D, Permute, Dropout, Bidirectional
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Data Incertion

# %%
# Data incerted
raw_data = np.loadtxt('/content/drive/MyDrive/Exoplanet_Detect/exoTrain.csv', skiprows=1, delimiter=',')
X_train = raw_data[:, 1:]
y_train = raw_data[:, 0, np.newaxis] - 1.
raw_data = np.loadtxt('/content/drive/MyDrive/Exoplanet_Detect/exoTest.csv', skiprows=1, delimiter=',')
X_test = raw_data[:, 1:]
y_test = raw_data[:, 0, np.newaxis] - 1.
#del raw_data

# %%
pd.read_csv('/content/drive/MyDrive/Exoplanet_Detect/exoTest.csv').head(10)
# Out:
#    LABEL   FLUX.1   FLUX.2   FLUX.3   FLUX.4   FLUX.5   FLUX.6   FLUX.7  \
# 0      2   119.88   100.21    86.46    48.68    46.12    39.39    18.57
# 1      2  5736.59  5699.98  5717.16  5692.73  5663.83  5631.16  5626.39
# 2      2   844.48   817.49   770.07   675.01   605.52   499.45   440.77
# 3      2  -826.00  -827.31  -846.12  -836.03  -745.50  -784.69  -791.22
# 4      2   -39.57   -15.88    -9.16    -6.37   -16.13   -24.05    -0.90
# 5      1    14.28    10.63    14.56    12.42    12.07    12.92    12.27
# 6      1  -150.48  -141.72  -157.60  -184.60  -164.89  -173.87  -162.91
# 7      1   -10.06   -12.78   -13.16    -9.81   -18.91   -20.33   -22.85
# 8      1   454.66   440.60   382.29   361.63   298.63   253.29   155.86
# 9      1   187.40   209.60   199.91   179.62   171.21   161.84   163.02
#
#     FLUX.8   FLUX.9  ...  FLUX.3188  FLUX.3189  FLUX.3190  FLUX.3191  \
# 0     6.98     6.63  ...      14.52      19.29      14.44      -1.62
# 1  5569.47  5550.44  ...    -581.91    -984.09   -1230.89   -1600.45
# 2   362.95   207.27  ...      17.82     -51.66     -48.29     -59.99
# 3  -746.50  -709.53  ...     122.34      93.03      93.03      68.81
# 4   -45.20    -5.04  ...     -37.87     -61.85     -27.15     -21.18
# 5     3.19     8.47  ...       3.86      -4.06      -3.56      -1.13
# 6  -167.04  -172.76  ...       7.15       5.16      -9.08     -39.11
# 7   -19.17   -17.97  ...      21.49      30.63      24.19      33.00
# 8   110.38    31.71  ...     -56.78     -61.64    -120.32     -65.39
# 9   171.61   113.53  ...     -23.75     -35.72     -21.93     -16.47
#
#    FLUX.3192  FLUX.3193  FLUX.3194  FLUX.3195  FLUX.3196  FLUX.3197
# 0      13.33      45.50      31.93      35.78     269.43      57.72
# 1   -1824.53   -2061.17   -2265.98   -2366.19   -2294.86   -2034.72
# 2     -82.10    -174.54     -95.23    -162.68     -36.79      30.63
# 3       9.81      20.75      20.25    -120.81    -257.56    -215.41
# 4     -33.76     -85.34     -81.46     -61.98     -69.34     -17.84
# 5      -7.18      -4.78      -4.34       7.67      -0.33      -7.53
# 6     -32.31      -8.40     -16.80      -8.03     -12.73     -11.41
# 7      35.70      35.89     -33.44     -30.83     -33.00     -20.15
# 8    -126.75     -78.18    -184.39    -142.31    -113.12    -111.78
# 9     -21.84     -26.64     -13.90      17.03       4.36       2.91
#
# [10 rows x 3198 columns]

# %%
X_train,X_train.shape
# Out:
# (array([[ 93.85,  83.81,  20.1 , ...,  61.42,   5.08, -39.54],
#         [-38.88, -33.83, -58.54, ...,   6.46,  16.  ,  19.93],
#         [532.64, 535.92, 513.73, ..., -28.91, -70.02, -96.67],
#         ...,
#         [273.39, 278.  , 261.73, ...,  88.42,  79.07,  79.43],
#         [  3.82,   2.09,  -3.29, ..., -14.55,  -6.41,  -2.55],
#         [323.28, 306.36, 293.16, ..., -16.72, -14.09,  27.82]]),
#  (5087, 3197))

# %% [markdown]
# # Data Visualization

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = X_train[y_train[:, 0] == c]
    plt.plot(c_x_train[1], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# # Visualizing Class Imbalance

# %%
import matplotlib.pyplot as plt

# Calculate class distribution
class_counts = np.bincount(y_train.flatten().astype(int))

# Plot class distribution
plt.bar(np.unique(y_train.flatten()), class_counts)
plt.xlabel('Class Label')
plt.ylabel('Number of Samples')
plt.title('Class Distribution')
plt.show()

# %%
from imblearn.over_sampling import SMOTE, ADASYN
from imblearn.under_sampling import OneSidedSelection
from imblearn.pipeline import Pipeline

# Define a pipeline for SMOTE + OSS
smote_oss_pipeline = Pipeline([
    ('smote', SMOTE(sampling_strategy=0.20, k_neighbors=5)),
    ('oss', OneSidedSelection(n_neighbors=5, n_seeds_S=1500))
])

# Apply the pipeline to your data
X_train_smote_oss, y_train_smote_oss = smote_oss_pipeline.fit_resample(X_train, y_train)

# Define a pipeline for ADASYN + OSS
adasyn_oss_pipeline = Pipeline([
    ('adasyn', ADASYN(sampling_strategy=0.20, n_neighbors=5)),
    ('oss', OneSidedSelection(n_neighbors=5, n_seeds_S=1500))
])

# Apply the pipeline to your data
X_train_adasyn_oss, y_train_adasyn_oss = adasyn_oss_pipeline.fit_resample(X_train, y_train)

# %% [markdown]
# #Data after Oversampling and Undersampling

# %%
import matplotlib.pyplot as plt

# Calculate class distribution
class_counts = np.bincount(y_train_smote_oss.flatten().astype(int))

# Plot class distribution
plt.bar(np.unique(y_train_smote_oss.flatten()), class_counts)
plt.xlabel('Class Label')
plt.ylabel('Number of Samples')
plt.title('Class Distribution(SMOTE+OSS)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate class distribution
class_counts = np.bincount(y_train_adasyn_oss.flatten().astype(int))

# Plot class distribution
plt.bar(np.unique(y_train_adasyn_oss.flatten()), class_counts)
plt.xlabel('Class Label')
plt.ylabel('Number of Samples')
plt.title('Class Distribution(ADASYN+OSS)')
plt.show()

# %% [markdown]
# # Using ADASYN + OSS

# %%
X_train, y_train = X_train_adasyn_oss, y_train_adasyn_oss

# %% [markdown]
# # Normalizing the data
# Our timeseries are already in a single length (500). However, their values are usually in various ranges. This is not ideal for a neural network; in general we should seek to make the input values normalized. For this specific dataset, the data is already z-normalized: each timeseries sample has a mean equal to zero and a standard deviation equal to one. This type of normalization is very common for timeseries classification problems, see Bagnall et al. (2016).
#
# Note that the timeseries data used here are univariate, meaning we only have one channel per timeseries example. We will therefore transform the timeseries into a multivariate one with one channel using a simple reshaping via numpy. This will allow us to construct a model that is easily applicable to multivariate time series. (**Coppied Needs to e Updated**)

# %%
''' Normalizing the training and testing data features
    (x_train and x_test) using z-score normalization, also known
    as standardization.
'''

X_train = ((X_train - np.mean(X_train, axis=1).reshape(-1,1)) /
           np.std(X_train, axis=1).reshape(-1,1))
X_test = ((X_test - np.mean(X_test, axis=1).reshape(-1,1)) /
          np.std(X_test, axis=1).reshape(-1,1))

# %% [markdown]
# # Reshaping The Data

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
x_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# Finally, in order to use sparse_categorical_crossentropy, we will have to count the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Now we shuffle the training set because we will be using the validation_split option later when training.

# %%
idx = np.random.permutation(len(X_train))
X_train = X_train[idx]
y_train = y_train[idx]

# %%
X_test.shape
# Out:
# (570, 3197)

# %% [markdown]
# # Build a Model

# %%
def fcn_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=128, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=256, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=128, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    out = keras.layers.Dropout(0.2)(gap)
    #output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)
    hidden_layer=
    return out#keras.models.Model(inputs=input_layer, outputs=output_layer)


model_fcn = fcn_model(input_shape=X_train.shape[1:])
#keras.utils.plot_model(model, show_shapes=True)
#model_fcn.summary()

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

def lstm_model(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)
    x = layers.LSTM(64, return_sequences=True)(inputs)
    #x = layers.Dropout(0.2)(x)
    x = layers.LSTM(128, return_sequences=True)(x)
    #x = layers.Dropout(0.2)(x)
    x = (layers.LSTM(128))(x)
    #x = layers.Dropout(0.2)(x)
    x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.01))(x)
    x = layers.Dropout(0.25)(x)

    outputs = layers.Dense(1, activation='sigmoid')(x)
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model


# Example usage:
model_lstm = lstm_model(input_shape=X_train.shape[1:], num_classes=num_classes)

# %%
import tensorflow as tf
from tensorflow.keras import layers
input_shape=X_train.shape[1:]
def lstm_model(input_shape):
    model = tf.keras.Sequential([
        layers.Bidirectional(layers.LSTM(64, return_sequences=True), input_shape=input_shape),
        layers.Dropout(0.2),
        layers.Bidirectional(layers.LSTM(128, return_sequences=True)),
        layers.Dropout(0.2),
        layers.Bidirectional(layers.LSTM(128)),
        layers.Dropout(0.2),
        layers.Dense(2, activation='softmax')])
    return model
# Example usage:
#input_shape = (input_shape, num_features)  # Define your input shape
model = lstm_model(input_shape)

# %%
#Concatenate
x = concatenate([model_fcn, model_lstm])
x = Dense(32, activation='relu')(x)
out = Dense(1, activation='sigmoid')(x)
model_cnn_lstm = Model(tf.keras.input=input_shape, out)
model_cnn_lstm.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-8311b29b6ba2> in <cell line: 5>()
#       3 x = Dense(32, activation='relu')(x)
#       4 out = Dense(1, activation='sigmoid')(x)
# ----> 5 model_cnn_lstm = Model(input_shape, out)
#       6 model_cnn_lstm.summary()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in __init__(self, inputs, outputs, name, trainable, **kwargs)
#     156         if tf.compat.v1.executing_eagerly_outside_functions():
#     157             if not all(
# --> 158                 [
#     159                     functional_utils.is_input_keras_tensor(t)
#     160                     for t in tf.nest.flatten(inputs)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py in <listcomp>(.0)
#     157             if not all(
#     158                 [
# --> 159                     functional_utils.is_input_keras_tensor(t)
#     160                     for t in tf.nest.flatten(inputs)
#     161                 ]
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/functional_utils.py in is_input_keras_tensor(tensor)
#      46     """
#      47     if not node_module.is_keras_tensor(tensor):
# ---> 48         raise ValueError(_KERAS_TENSOR_TYPE_CHECK_ERROR_MSG.format(tensor))
#      49     return tensor.node.is_input
#      50
#
# ValueError: Found unexpected instance while processing input tensors for keras functional model. Expecting KerasTensor which is from tf.keras.Input() or output from keras layer call(). Got: 3197

# %%
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-470475b61677> in <cell line: 1>()
# ----> 1 keras.utils.plot_model(model, show_shapes=True)
#
# NameError: name 'model' is not defined

# %%
#resnet
import tensorflow as tf
from tensorflow.keras import layers

def convolutional_block(x, filters, kernel_size=3):
    y = layers.Conv1D(filters, kernel_size, padding='same')(x)
    y = layers.BatchNormalization()(y)
    y = layers.ReLU()(y)
    return y

def residual_blocks(x, filters, num_blocks):
    for _ in range(num_blocks):
        x = convolutional_block(x, filters)
    return x

def resnet(input_shape, num_classes):
    inputs = tf.keras.Input(shape=input_shape)

    # Initial convolutional layer
    x = layers.Conv1D(64, 7, strides=2, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling1D(3, strides=2, padding='same')(x)

    # Residual blocks
    x = residual_blocks(x, 64, 3)
    x = residual_blocks(x, 128, 3)
    x = residual_blocks(x, 128, 3)

    # Global average pooling and output
    x = layers.GlobalAveragePooling1D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    return tf.keras.Model(inputs, outputs)

# Example usage:
input_shape = X_train.shape[1:]  # Define your input shape
num_classes = 2  # Define the number of classes
model = resnet(input_shape, num_classes)

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
X_train.shape
# Out:
# (2721, 3197, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                stratify=y_train,
                                                test_size=0.25)

# %%
X_train.shape
# Out:
# (2040, 3197, 1)

# %% [markdown]
# # Train the model

# %%
epochs = 100
batch_size = 32
EarlyStopping=keras.callbacks.EarlyStopping(verbose=1, patience=20, monitor="val_accuracy", mode="max",restore_best_weights=True)

# callbacks = [
#     keras.callbacks.ModelCheckpoint(
#         "best_model.keras", save_best_only=True, monitor="val_loss"
#     ),
#     keras.callbacks.ReduceLROnPlateau(
#         monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
#     ),
#     keras.callbacks.EarlyStopping(monitor="val_loss", patience=20, verbose=1),
# ]
model_lstm.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
history = model_lstm.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[EarlyStopping],
    #validation_split=0.2
    validation_data=(X_val,y_val)
)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 28s 373ms/step - loss: 0.6048 - accuracy: 0.6921 - val_loss: 0.5774 - val_accuracy: 0.7183
# Epoch 2/100
# 60/60 [==============================] - 19s 307ms/step - loss: 0.4945 - accuracy: 0.7638 - val_loss: 0.4115 - val_accuracy: 0.8180
# Epoch 3/100
# 60/60 [==============================] - 19s 317ms/step - loss: 0.4381 - accuracy: 0.8023 - val_loss: 0.4334 - val_accuracy: 0.8118
# Epoch 4/100
# 60/60 [==============================] - 18s 308ms/step - loss: 0.3594 - accuracy: 0.8487 - val_loss: 0.3076 - val_accuracy: 0.8696
# Epoch 5/100
# 60/60 [==============================] - 19s 310ms/step - loss: 0.3529 - accuracy: 0.8419 - val_loss: 0.3424 - val_accuracy: 0.8499
# Epoch 6/100
# 60/60 [==============================] - 21s 348ms/step - loss: 0.3068 - accuracy: 0.8698 - val_loss: 0.3239 - val_accuracy: 0.8573
# Epoch 7/100
# 60/60 [==============================] - 19s 309ms/step - loss: 0.3077 - accuracy: 0.8693 - val_loss: 0.2869 - val_accuracy: 0.8930
# Epoch 8/100
# 60/60 [==============================] - 19s 310ms/step - loss: 0.2626 - accuracy: 0.8925 - val_loss: 0.2303 - val_accuracy: 0.9164
# Epoch 9/100
# 60/60 [==============================] - 21s 353ms/step - loss: 0.1818 - accuracy: 0.9341 - val_loss: 0.2040 - val_accuracy: 0.9299
# Epoch 10/100
# 60/60 [==============================] - 21s 347ms/step - loss: 0.2109 - accuracy: 0.9209 - val_loss: 0.2941 - val_accuracy: 0.8770
# Epoch 11/100
# 60/60 [==============================] - 21s 353ms/step - loss: 0.1888 - accuracy: 0.9325 - val_loss: 0.1954 - val_accuracy: 0.9323
# Epoch 12/100
# 60/60 [==============================] - 21s 352ms/step - loss: 0.2145 - accuracy: 0.9241 - val_loss: 0.2819 - val_accuracy: 0.8967
# Epoch 13/100
# 60/60 [==============================] - 21s 354ms/step - loss: 0.2369 - accuracy: 0.9067 - val_loss: 0.1864 - val_accuracy: 0.9311
# Epoch 14/100
# 60/60 [==============================] - 21s 354ms/step - loss: 0.1728 - accuracy: 0.9362 - val_loss: 0.2008 - val_accuracy: 0.9200
# Epoch 15/100
# 60/60 [==============================] - 20s 326ms/step - loss: 0.1876 - accuracy: 0.9341 - val_loss: 0.1788 - val_accuracy: 0.9274
# Epoch 16/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.1005 - accuracy: 0.9731 - val_loss: 0.1454 - val_accuracy: 0.9496
# Epoch 36/100
# 60/60 [==============================] - 21s 351ms/step - loss: 0.0914 - accuracy: 0.9742 - val_loss: 0.1819 - val_accuracy: 0.9385
# Epoch 37/100
# 60/60 [==============================] - 21s 355ms/step - loss: 0.1079 - accuracy: 0.9652 - val_loss: 0.2261 - val_accuracy: 0.9188
# Epoch 38/100
# 60/60 [==============================] - 19s 315ms/step - loss: 0.1293 - accuracy: 0.9584 - val_loss: 0.1507 - val_accuracy: 0.9533
# Epoch 39/100
# 60/60 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9721Restoring model weights from the end of the best epoch: 19.
# 60/60 [==============================] - 19s 324ms/step - loss: 0.0983 - accuracy: 0.9721 - val_loss: 0.1597 - val_accuracy: 0.9397
# Epoch 39: early stopping

# %%
import matplotlib.pyplot as plt
from PIL import Image

colors = ['blue','orange']
plt.figure(figsize=(15, 12))
metrics = ['accuracy', 'loss']

for i, metric in enumerate(metrics):
    plt.subplot(220 + 1 + i)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_' + metric],
                color=colors[1], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(metric)
    plt.legend()
    plt.show()

# %%
y_pred_indices.shape
# Out:
# (570, 2)

# %%
# Get the predicted class indices using model.predict and np.argmax
y_pred_indices = model_lstm.predict(x_test)
import numpy as np

# Assuming y_pred_indices is a numpy array with continuous values
# Thresholding operation: if less than 0.5, set to 0; otherwise, set to 1
y_pred_binary = np.where(y_pred_indices < 0.5, 0, 1)

# Get the class names from the y_train dataset
class_names=['Non-exoplanet','Exoplanet']

# Generate and print the classification report
print(classification_report(y_test, y_pred_binary, target_names=class_names))
# Out:
# 18/18 [==============================] - 36s 111ms/step
#                precision    recall  f1-score   support
#
# Non-exoplanet       0.99      0.95      0.97       565
#     Exoplanet       0.00      0.00      0.00         5
#
#      accuracy                           0.94       570
#     macro avg       0.50      0.48      0.49       570
#  weighted avg       0.98      0.94      0.96       570

# %%
# Generate the confusion matrix
import seaborn as sns
cm = confusion_matrix(y_test, y_pred_binary)

# Set the font scale
sns.set(font_scale=1.5)

# Plot the heatmap
plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(2)+.5, class_names, rotation=25)
plt.yticks(np.arange(2)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
model.evaluate(x_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-4d42213cd169> in <cell line: 1>()
# ----> 1 model.evaluate(x_test,y_test)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2294                         ):
#    2295                             callbacks.on_test_batch_begin(step)
# -> 2296                             logs = test_function_runner.run_step(
#    2297                                 dataset_or_iterator,
#    2298                                 data_handler,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in run_step(self, dataset_or_iterator, data_handler, step, unused_shards)
#    4106
#    4107     def run_step(self, dataset_or_iterator, data_handler, step, unused_shards):
# -> 4108         tmp_logs = self._function(dataset_or_iterator)
#    4109         if data_handler.should_sync:
#    4110             context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     875       # In this case we have not created variables on the first call. So we can
#     876       # run the first trace but we should fail if variables are created.
# --> 877       results = tracing_compilation.call_function(
#     878           args, kwds, self._variable_creation_config
#     879       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     130   args = args if args else ()
#     131   kwargs = kwargs if kwargs else {}
# --> 132   function = trace_function(
#     133       args=args, kwargs=kwargs, tracing_options=tracing_options
#     134   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in trace_function(args, kwargs, tracing_options)
#     176       kwargs = {}
#     177
# --> 178     concrete_function = _maybe_define_function(
#     179         args, kwargs, tracing_options
#     180     )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _maybe_define_function(args, kwargs, tracing_options)
#     281         else:
#     282           target_func_type = lookup_func_type
# --> 283         concrete_function = _create_concrete_function(
#     284             target_func_type, lookup_func_context, func_graph, tracing_options
#     285         )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     308       attributes_lib.DISABLE_ACD, False
#     309   )
# --> 310   traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311       tracing_options.name,
#     312       tracing_options.python_function,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in wrapped_fn(*args, **kwds)
#     596         # the function a weak reference to itself to avoid a reference cycle.
#     597         with OptionalXlaContext(compile_with_xla):
# --> 598           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599         return out
#     600
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py in autograph_handler(*args, **kwargs)
#      39     """Calls a converted version of original_func."""
#      40     try:
# ---> 41       return api.converted_call(
#      42           original_func,
#      43           args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437     try:
#     438       if kwargs is not None:
# --> 439         result = converted_f(*effective_args, **kwargs)
#     440       else:
#     441         result = converted_f(*effective_args)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__test_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329   if conversion.is_in_allowlist_cache(f, options):
#     330     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331     return _call_unconverted(f, args, kwargs, options, False)
#     332
#     333   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     458   if kwargs is not None:
#     459     return f(*args, **kwargs)
# --> 460   return f(*args)
#     461
#     462
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in step_function(model, iterator)
#    2047
#    2048             data = next(iterator)
# -> 2049             outputs = model.distribute_strategy.run(run_step, args=(data,))
#    2050             outputs = reduce_per_replica(
#    2051                 outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in run(***failed resolving arguments***)
#    1679       fn = autograph.tf_convert(
#    1680           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1681       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#    1682
#    1683   def reduce(self, reduce_op, value, axis):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in call_for_each_replica(self, fn, args, kwargs)
#    3269       kwargs = {}
#    3270     with self._container_strategy().scope():
# -> 3271       return self._call_for_each_replica(fn, args, kwargs)
#    3272
#    3273   def _call_for_each_replica(self, fn, args, kwargs):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/distribute/distribute_lib.py in _call_for_each_replica(self, fn, args, kwargs)
#    4067   def _call_for_each_replica(self, fn, args, kwargs):
#    4068     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4069       return fn(*args, **kwargs)
#    4070
#    4071   def _reduce_to(self, reduce_op, value, destinations, options):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     375
#     376   if not options.user_requested and conversion.is_allowlisted(f):
# --> 377     return _call_unconverted(f, args, kwargs, options)
#     378
#     379   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in run_step(data)
#    2035
#    2036             def run_step(data):
# -> 2037                 outputs = model.test_step(data)
#    2038                 # Ensure counter is updated only if `test_step` succeeds.
#    2039                 with tf.control_dependencies(_minimum_control_deps(outputs)):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in test_step(self, data)
#    1917         y_pred = self(x, training=False)
#    1918         # Updates stateful loss metrics.
# -> 1919         self.compute_loss(x, y, y_pred, sample_weight)
#    1920         return self.compute_metrics(x, y, y_pred, sample_weight)
#    1921
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in compute_loss(***failed resolving arguments***)
#    1207         """
#    1208         del x  # The default implementation does not use `x`.
# -> 1209         return self.compiled_loss(
#    1210             y, y_pred, sample_weight, regularization_losses=self.losses
#    1211         )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/compile_utils.py in __call__(self, y_true, y_pred, sample_weight, regularization_losses)
#     275             y_t, y_p, sw = match_dtype_and_rank(y_t, y_p, sw)
#     276             sw = losses_utils.apply_mask(y_p, sw, losses_utils.get_mask(y_p))
# --> 277             loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     278
#     279             total_loss_mean_value = loss_value
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in __call__(self, y_true, y_pred, sample_weight)
#     141                 )
#     142
# --> 143             losses = call_fn(y_true, y_pred)
#     144
#     145             in_mask = losses_utils.get_mask(y_pred)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     688       try:
#     689         with conversion_ctx:
# --> 690           return converted_call(f, args, kwargs, options=options)
#     691       except Exception as e:  # pylint:disable=broad-except
#     692         if hasattr(e, 'ag_error_metadata'):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329   if conversion.is_in_allowlist_cache(f, options):
#     330     logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331     return _call_unconverted(f, args, kwargs, options, False)
#     332
#     333   if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/autograph/impl/api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     457
#     458   if kwargs is not None:
# --> 459     return f(*args, **kwargs)
#     460   return f(*args)
#     461
#
# /usr/local/lib/python3.10/dist-packages/keras/src/losses.py in call(self, y_true, y_pred)
#     261         """
#     262         if tf.is_tensor(y_pred) and tf.is_tensor(y_true):
# --> 263             y_pred, y_true = losses_utils.squeeze_or_expand_dimensions(
#     264                 y_pred, y_true
#     265             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/losses_utils.py in squeeze_or_expand_dimensions(y_pred, y_true, sample_weight)
#     207                 is_last_dim_1, squeeze_dims, lambda: (y_true, y_pred)
#     208             )
# --> 209             y_true, y_pred = tf.cond(
#     210                 tf.equal(1, rank_diff), maybe_squeeze_dims, squeeze_dims
#     211             )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond.py in cond_for_tf_v2(pred, true_fn, false_fn, name)
#     341
#     342   """
# --> 343   return cond(pred, true_fn=true_fn, false_fn=false_fn, strict=True, name=name)
#     344
#     345
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     586                 'in a future version' if date is None else ('after %s' % date),
#     587                 instructions)
# --> 588       return func(*args, **kwargs)
#     589
#     590     doc = _add_deprecated_arg_notice_to_docstring(
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond.py in cond(pred, true_fn, false_fn, strict, name, fn1, fn2)
#     144   # Always enable control flow v2 if building a function, regardless of toggle.
#     145   if util.EnableControlFlowV2(ops.get_default_graph()):
# --> 146     return cond_v2.cond_v2(pred, true_fn, false_fn, name)
#     147
#     148   with ops.name_scope(name, "cond", [pred]):
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/cond_v2.py in cond_v2(pred, true_fn, false_fn, name)
#      87         add_control_dependencies=add_control_dependencies,
#      88         op_return_value=pred)
# ---> 89     false_graph = func_graph_module.func_graph_from_py_func(
#      90         false_name,
#      91         false_fn, [], {},
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057
#    1058     _, original_func = tf_decorator.unwrap(python_func)
# -> 1059     func_outputs = python_func(*func_args, **func_kwargs)
#    1060
#    1061     # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/losses_utils.py in <lambda>()
#     202             # Use dynamic rank.
#     203             rank_diff = tf.rank(y_pred) - tf.rank(y_true)
# --> 204             squeeze_dims = lambda: remove_squeezable_dimensions(y_true, y_pred)
#     205             is_last_dim_1 = tf.equal(1, tf.shape(y_pred)[-1])
#     206             maybe_squeeze_dims = lambda: tf.cond(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/losses_utils.py in remove_squeezable_dimensions(labels, predictions, expected_rank_diff, name)
#     154         ):
#     155             labels = tf.cond(
# --> 156                 tf.equal(expected_rank_diff - 1, rank_diff),
#     157                 lambda: tf.squeeze(labels, [-1]),
#     158                 lambda: labels,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/math_ops.py in equal(x, y, name)
#    2035     `tf.errors.InvalidArgumentError`: If shapes of arguments are incompatible
#    2036   """
# -> 2037   return gen_math_ops.equal(x, y, name=name)
#    2038
#    2039
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/weak_tensor_ops.py in wrapper(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_math_ops.py in equal(x, y, incompatible_shape_error, name)
#    3414     incompatible_shape_error = True
#    3415   incompatible_shape_error = _execute.make_bool(incompatible_shape_error, "incompatible_shape_error")
# -> 3416   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    3417         "Equal", x=x, y=y, incompatible_shape_error=incompatible_shape_error,
#    3418                  name=name)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     753   """Implementation of apply_op that returns output_structure, op."""
#     754
# --> 755   op_def, g, producer = _GetOpDef(op_type_name, keywords)
#     756   name = name if name else op_type_name
#     757
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/op_def_library.py in _GetOpDef(op_type_name, keywords)
#     733     # pylint: disable=protected-access
#     734     g = ops._get_graph_from_inputs(_Flatten(keywords.values()))
# --> 735     producer = g.graph_def_versions.producer
#     736     # pylint: enable=protected-access
#     737   except AssertionError as e:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in graph_def_versions(self)
#    2237       A `VersionDef`.
#    2238     """
# -> 2239     return versions_pb2.VersionDef.FromString(self._version_def)
#    2240
#    2241   @property
#
# KeyboardInterrupt:

# %%
# Get the predicted class indices using model.predict and np.argmax
y_pred_indices = np.argmax(model_lstm.predict(x_test), axis=1)

# Get the class names from the y_train dataset
class_names=['Non-exoplanet','Exoplanet']

# Generate and print the classification report
print(classification_report(y_test, y_pred_indices, target_names=class_names))
# Out:
# 18/18 [==============================] - 6s 233ms/step
#                precision    recall  f1-score   support
#
# Non-exoplanet       0.99      0.97      0.98       565
#     Exoplanet       0.00      0.00      0.00         5
#
#      accuracy                           0.96       570
#     macro avg       0.50      0.49      0.49       570
#  weighted avg       0.98      0.96      0.97       570

# %%
# Generate the confusion matrix
import seaborn as sns
cm = confusion_matrix(y_test, y_pred_indices)

# Set the font scale
sns.set(font_scale=1.5)

# Plot the heatmap
plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(2)+.5, class_names, rotation=25)
plt.yticks(np.arange(2)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
'''plt.savefig('temp_plot.jpeg')
temp_plot = Image.open('temp_plot.jpeg')
temp_plot.save('acc_loss_1.jpeg')
temp_plot.close()
os.remove('temp_plot.jpeg')'''
# Out:
# "plt.savefig('temp_plot.jpeg')\ntemp_plot = Image.open('temp_plot.jpeg')\ntemp_plot.save('acc_loss_1.jpeg')\ntemp_plot.close()\nos.remove('temp_plot.jpeg')"

# %% [markdown]
# # Evaluate model on test data

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-25-049b564896fd> in <cell line: 1>()
# ----> 1 model = keras.models.load_model("best_model.keras")
#       2
#       3 test_loss, test_acc = model.evaluate(x_test, y_test)
#       4
#       5 print("Test accuracy", test_acc)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     260
#     261     # Legacy case.
# --> 262     return legacy_sm_saving_lib.load_model(
#     263         filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264     )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/legacy/save.py in load_model(filepath, custom_objects, compile, options)
#     232                     if isinstance(filepath_str, str):
#     233                         if not tf.io.gfile.exists(filepath_str):
# --> 234                             raise IOError(
#     235                                 f"No file or directory found at {filepath_str}"
#     236                             )
#
# OSError: No file or directory found at best_model.keras

# %% [markdown]
# # Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# *Etar pore oporer code ta copy kore (ADASYN+OSS) e apply koris dakh kichu change ase kina. Etar niche koris.Oporer ta run koris epoch=100 kore ar early stoping marbi. Confusion matrix tao print koriye dis.*

# %%
import matplotlib.pyplot as plt

# Calculate class distribution
class_counts = np.bincount(y_train_adasyn_oss.flatten().astype(int))

# Plot class distribution
plt.bar(np.unique(y_train_adasyn_oss.flatten()), class_counts)
plt.xlabel('Class Label')
plt.ylabel('Number of Samples')
plt.title('Class Distribution(ADASYN+OSS)')
plt.show()

# %%
# Adding the validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, stratify=y_train,
                                                  test_size=0.3, random_state=123)

# %%
print(X_train.shape)
print(X_val.shape)
# Out:
# (1897, 3197, 1)
# (813, 3197, 1)

# %%
# Reshaping the data

np.set_printoptions(threshold=np.inf)
X_train_r = np.expand_dims(X_train, axis=2)
X_val_r = np.expand_dims(X_val, axis=2)
X_test = np.expand_dims(X_test, axis=2)

# %%
print(X_train_r.shape)
print(X_test.shape)
# Out:
# (1897, 3197, 1, 1)
# (570, 3197, 1)

# %%
def batch_generator(X_train, y_train, batch_size=32):
    """
    Generates batches of training data with equal number of positive and
    negative samples, and rotates them randomly in time to augment the data
    """
    half_batch = batch_size // 2
    X_batch = np.empty((batch_size, X_train.shape[1], X_train.shape[2]), dtype='float32')
    y_batch = np.empty((batch_size, y_train.shape[1], dtype='float32')

    #Get the indices of positive(exoplanet) and negative(non-exoplanet) samples in the training data.
    yes_idx = np.where(y_train[:,0] == 1.)[0]
    non_idx = np.where(y_train[:,0] == 0.)[0]

    while True:
        np.random.shuffle(yes_idx)
        np.random.shuffle(non_idx)

        X_batch[:half_batch] = X_train[yes_idx[:half_batch]]
        X_batch[half_batch:] = X_train[non_idx[half_batch:batch_size]]
        y_batch[:half_batch] = y_train[yes_idx[:half_batch]]
        y_batch[half_batch:] = y_train[non_idx[half_batch:batch_size]]

        for i in range(batch_size):
            sz = np.random.randint(X_batch.shape[1])
            X_batch[i] = np.roll(X_batch[i], sz, axis = 0)

        yield X_batch, y_batch

# %%
# Creating the model
ip = Input(shape=(3197, 1))

# %% [markdown]
# # KNN

# %% [markdown]
# # SVM

# %% [markdown]
# # Decision Tree

# %% [markdown]
# # Random Forest
# \

# %%
# 1D-CNN
y = Conv1D(filters=16, kernel_size=11, activation='relu')(ip)
y = MaxPool1D(strides=4)(y)
y = BatchNormalization()(y)
y = Conv1D(filters=32, kernel_size=11, activation='relu')(y)
y = MaxPool1D(strides=4)(y)
y = BatchNormalization()(y)
y = Conv1D(filters=64, kernel_size=11, activation='relu')(y)
y = MaxPool1D(strides=4)(y)
# y = BatchNormalization()(y)
# y = Conv1D(filters=128, kernel_size=11, activation='relu')(y)
# y = MaxPool1D(strides=4)(y)
y = Flatten()(y)
y = Dropout(0.25)(y)
y = Dense(64, activation='relu')(y)

# %% [markdown]
# #Simple CNN

# %%
out = Dense(1, activation='sigmoid')(y)
model_cnn = Model(ip,out)
model_cnn.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3197, 1)]         0
#
#  conv1d (Conv1D)             (None, 3187, 16)          192
#
#  max_pooling1d (MaxPooling1  (None, 797, 16)           0
#  D)
#
#  batch_normalization (Batch  (None, 797, 16)           64
#  Normalization)
#
#  conv1d_1 (Conv1D)           (None, 787, 32)           5664
#
#  max_pooling1d_1 (MaxPoolin  (None, 197, 32)           0
#  g1D)
#
#  batch_normalization_1 (Bat  (None, 197, 32)           128
#  chNormalization)
#
#  conv1d_2 (Conv1D)           (None, 187, 64)           22592
#
#  max_pooling1d_2 (MaxPoolin  (None, 47, 64)            0
#  g1D)
#
#  flatten (Flatten)           (None, 3008)              0
#
#  dropout (Dropout)           (None, 3008)              0
#
#  dense (Dense)               (None, 64)                192576
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 221281 (864.38 KB)
# Trainable params: 221185 (864.00 KB)
# Non-trainable params: 96 (384.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
# Plot the model architecture
plot_model(model_cnn, to_file='/content/drive/MyDrive/Dataset/Outputs/model_cnn.png', show_shapes=True, show_layer_names=True)

# %%
model_cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
EarlyStopping=keras.callbacks.EarlyStopping(verbose=1, patience=20, monitor="accuracy", mode="max",restore_best_weights=True)


'''model_cnn.fit_generator(batch_generator(X_train_r, y_train, 32),
                           validation_data=(X_val_r, y_val),
                           epochs=100,
                           steps_per_epoch=X_train_r.shape[1]//32,
                           callbacks=[EarlyStopping],
                           verbose=1)'''

history = model_cnn.fit(X_train, y_train, batch_size=32, epochs = 100, validation_data=(X_val,y_val), callbacks = [EarlyStopping])
# Out:
# Epoch 1/100
# 60/60 [==============================] - 10s 18ms/step - loss: 0.1924 - accuracy: 0.9141 - val_loss: 0.2208 - val_accuracy: 0.9779
# Epoch 2/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0203 - accuracy: 0.9958 - val_loss: 0.1024 - val_accuracy: 0.9963
# Epoch 3/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.0491 - val_accuracy: 0.9938
# Epoch 4/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0086 - accuracy: 0.9979 - val_loss: 0.0192 - val_accuracy: 0.9963
# Epoch 5/100
# 60/60 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 0.0095 - val_accuracy: 0.9975
# Epoch 6/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0029 - accuracy: 0.9984 - val_loss: 0.0075 - val_accuracy: 0.9975
# Epoch 7/100
# 60/60 [==============================] - 1s 9ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9975
# Epoch 8/100
# 60/60 [==============================] - 0s 7ms/step - loss: 4.4588e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 0.9975
# Epoch 9/100
# 60/60 [==============================] - 0s 7ms/step - loss: 3.5880e-04 - accuracy: 1.0000 - val_loss: 0.0056 - val_accuracy: 0.9975
# Epoch 10/100
# 60/60 [==============================] - 1s 9ms/step - loss: 2.7784e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9975
# Epoch 11/100
# 60/60 [==============================] - 1s 9ms/step - loss: 1.5589e-04 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9975
# Epoch 12/100
# 60/60 [==============================] - 1s 11ms/step - loss: 1.4499e-04 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9975
# Epoch 13/100
# 60/60 [==============================] - 1s 11ms/step - loss: 1.3091e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 0.9975
# Epoch 14/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.2229e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 0.9975
# Epoch 15/100
# 60/60 [==============================] - 1s 12ms/step - loss: 7.9134e-05 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9975
# Epoch 16/100
# 60/60 [==============================] - 1s 10ms/step - loss: 1.6922e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9975
# Epoch 17/100
# 60/60 [==============================] - 1s 12ms/step - loss: 6.5082e-05 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 0.9975
# Epoch 18/100
# 60/60 [==============================] - 1s 9ms/step - loss: 8.0890e-05 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9975
# Epoch 19/100
# 60/60 [==============================] - 0s 7ms/step - loss: 1.6755e-04 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 0.9975
# Epoch 20/100
# 60/60 [==============================] - 0s 8ms/step - loss: 6.3257e-05 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 0.9975
# Epoch 21/100
# 60/60 [==============================] - 0s 7ms/step - loss: 5.7497e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9975
# Epoch 22/100
# 60/60 [==============================] - 1s 9ms/step - loss: 3.5703e-05 - accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 0.9975
# Epoch 23/100
# 60/60 [==============================] - 0s 7ms/step - loss: 4.5495e-05 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 0.9975
# Epoch 24/100
# 60/60 [==============================] - 0s 8ms/step - loss: 3.7430e-05 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9975
# Epoch 25/100
# 60/60 [==============================] - 0s 7ms/step - loss: 3.0327e-05 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 0.9975
# Epoch 26/100
# 60/60 [==============================] - 0s 7ms/step - loss: 3.4109e-05 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9975
# Epoch 27/100
# 57/60 [===========================>..] - ETA: 0s - loss: 3.0161e-05 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 7.
# 60/60 [==============================] - 1s 10ms/step - loss: 3.0788e-05 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 0.9975
# Epoch 27: early stopping

# %%
metric = "loss"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
metric = "accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
print(y_pred_indices)
# Out:
# [[3.58400762e-01]
#  [5.08172363e-02]
#  [9.25832272e-01]
#  [9.62155468e-07]
#  [1.77432401e-06]
#  [1.81805293e-09]
#  [7.61106946e-08]
#  [2.13689049e-07]
#  [1.80855650e-08]
#  [1.94928393e-10]
#  [4.97398123e-09]
#  [9.82594839e-11]
#  [6.89419943e-09]
#  [1.45178927e-08]
#  [3.57683966e-10]
#  [1.70322467e-09]
#  [4.19039026e-09]
#  [3.12770054e-09]
#  [6.82930101e-12]
#  [1.54088298e-08]
#  [9.14206339e-06]
#  [1.24540126e-11]
#  [3.09497364e-06]
#  [4.70240730e-06]
#  [4.47006460e-10]
#  [1.16935901e-08]
#  [2.28418529e-08]
#  [1.96155452e-05]
#  [1.17456445e-07]
#  [8.01931776e-07]
#  [5.07725284e-09]
#  [1.00567055e-09]
#  [9.45415968e-10]
#  [1.25706421e-07]
#  [8.02136191e-10]
#  [1.75811887e-09]
#  [1.35796985e-10]
#  [1.86981297e-09]
#  [5.24033332e-08]
#  [1.38184878e-05]
#  [2.14206319e-09]
#  [2.12600049e-10]
#  [1.12287940e-04]
#  [1.19296672e-07]
#  [2.97423114e-10]
#  [1.60682329e-10]
#  [3.19471134e-08]
#  [1.15700538e-09]
#  [1.22806186e-05]
#  [2.69091572e-07]
#  [1.55803204e-09]
#  [2.25263246e-11]
#  [2.81492767e-08]
#  [5.89786664e-09]
#  [7.60426474e-06]
#  [8.27556832e-08]
#  [2.93888625e-09]
#  [4.16047915e-05]
#  [2.87062139e-05]
#  [2.57939337e-10]
#  [3.78376193e-08]
#  [1.41319231e-06]
#  [3.33365392e-07]
#  [4.70186147e-11]
#  [2.94641728e-10]
#  [7.12128578e-09]
#  [9.47801979e-08]
#  [1.20438671e-07]
#  [2.67134936e-08]
#  [2.15052087e-09]
#  [6.51918754e-07]
#  [3.92759262e-07]
#  [2.40001885e-08]
#  [5.68181990e-09]
#  [9.24306687e-10]
#  [1.58850991e-04]
#  [4.44309737e-12]
#  [6.61190169e-09]
#  [5.97983316e-08]
#  [4.27953051e-09]
#  [1.03883213e-08]
#  [4.31070818e-10]
#  [1.28886120e-08]
#  [2.50591076e-10]
#  [1.66480106e-06]
#  [3.83547922e-06]
#  [3.11971888e-07]
#  [1.39463950e-07]
#  [2.23961507e-07]
#  [4.68619237e-06]
#  [8.48457676e-12]
#  [3.93776678e-10]
#  [1.51404450e-02]
#  [1.45349599e-08]
#  [1.26211541e-09]
#  [2.34964437e-10]
#  [1.61125698e-07]
#  [1.99436329e-07]
#  [6.29693346e-08]
#  [2.81774305e-07]
#  [5.91264415e-09]
#  [1.17721041e-10]
#  [3.16710884e-06]]

# %%
# Get the predicted class indices using model.predict and np.argmax
y_pred_indices = model_cnn.predict(x_test)
import numpy as np

# Assuming y_pred_indices is a numpy array with continuous values
# Thresholding operation: if less than 0.5, set to 0; otherwise, set to 1
y_pred_binary = np.where(y_pred_indices < 0.5, 0, 1)

# Get the class names from the y_train dataset
class_names=['Non-exoplanet','Exoplanet']

# Generate and print the classification report
print(classification_report(y_test, y_pred_binary, target_names=class_names))
# Out:
# 18/18 [==============================] - 0s 5ms/step
#                precision    recall  f1-score   support
#
# Non-exoplanet       0.99      1.00      1.00       565
#     Exoplanet       0.50      0.20      0.29         5
#
#      accuracy                           0.99       570
#     macro avg       0.75      0.60      0.64       570
#  weighted avg       0.99      0.99      0.99       570

# %%
# Generate the confusion matrix
import seaborn as sns
cm = confusion_matrix(y_test, y_pred_binary)

# Set the font scale
sns.set(font_scale=1.5)

# Plot the heatmap
plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
plt.xticks(np.arange(2)+.5, class_names, rotation=25)
plt.yticks(np.arange(2)+.5, class_names, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
y_pred = model_cnn.predict(x=X_test)
# Out:
# 18/18 [==============================] - 0s 3ms/step

# %%
non_idx = np.where(y_test[:,0] == 0.)[0]
yes_idx = np.where(y_test[:,0] == 1.)[0]
plt.plot([y_pred[i] for i in yes_idx], 'bo', label='Positive Class Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Predicted Value')
plt.show()
plt.plot([y_pred[i] for i in non_idx], 'ro', label='Negative Class Predictions')
plt.show()

# %%
#ROC Area under curve
y_true = (y_test[:, 0] + 0.5).astype("int")
fpr, tpr, thresholds = roc_curve(y_true, y_pred)
plt.plot(thresholds, 1.-fpr)
plt.plot(thresholds, tpr)
plt.show()
crossover_index = np.min(np.where(1.-fpr <= tpr))
crossover_cutoff = thresholds[crossover_index]
crossover_specificity = 1.-fpr[crossover_index]
print("Crossover at {0:.2f} with specificity {1:.2f}".format(crossover_cutoff, crossover_specificity))
plt.plot(fpr, tpr)
plt.show()
print("ROC area under curve is {0:.2f}".format(roc_auc_score(y_true, y_pred)))
# Out:
# Crossover at 0.99 with specificity 1.00
# ROC area under curve is 1.00

# %%
predthr = np.where(y_pred > 0.5, 1, 0)
print(classification_report(y_test, predthr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00       565
#          1.0       0.62      1.00      0.77         5
#
#     accuracy                           0.99       570
#    macro avg       0.81      1.00      0.88       570
# weighted avg       1.00      0.99      1.00       570

# %%
print(confusion_matrix(y_test, predthr))
# Out:
# [[562   3]
#  [  0   5]]

# %% [markdown]
# # CNN+LSTM

# %%
ip= X_test.shape

# %%
# LSTM
x = Permute((2, 1))(ip)
x = LSTM(16, return_sequences=True)(x)
x = LSTM(32, return_sequences=True)(x)
# x = LSTM(64, return_sequences=True)(x)
# x = LSTM(128)(x)
x = LSTM(64)(x)
x = Dropout(0.25)(x)

# %%
# 1D-CNN
y = Conv1D(filters=16, kernel_size=11, activation='relu')(ip)
y = MaxPool1D(strides=4)(y)
y = BatchNormalization()(y)
y = Conv1D(filters=32, kernel_size=11, activation='relu')(y)
y = MaxPool1D(strides=4)(y)
y = BatchNormalization()(y)
y = Conv1D(filters=64, kernel_size=11, activation='relu')(y)
y = MaxPool1D(strides=4)(y)
# y = BatchNormalization()(y)
# y = Conv1D(filters=128, kernel_size=11, activation='relu')(y)
# y = MaxPool1D(strides=4)(y)
y = Flatten()(y)
y = Dropout(0.25)(y)
y = Dense(64, activation='relu')(y)

# %%
#Concatenate
x = concatenate([x, y])
x = Dense(32, activation='relu')(x)
out = Dense(2, activation='softmax')(x)
model_cnn_lstm = Model(ip, out)
model_cnn_lstm.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 3197, 1)]            0         []
#
#  conv1d (Conv1D)             (None, 3187, 16)             192       ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 797, 16)              0         ['conv1d[0][0]']
#  D)
#
#  batch_normalization (Batch  (None, 797, 16)              64        ['max_pooling1d[0][0]']
#  Normalization)
#
#  conv1d_1 (Conv1D)           (None, 787, 32)              5664      ['batch_normalization[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 197, 32)              0         ['conv1d_1[0][0]']
#  g1D)
#
#  batch_normalization_1 (Bat  (None, 197, 32)              128       ['max_pooling1d_1[0][0]']
#  chNormalization)
#
#  permute_2 (Permute)         (None, 1, 3197)              0         ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)           (None, 187, 64)              22592     ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  lstm (LSTM)                 (None, 1, 16)                205696    ['permute_2[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 47, 64)               0         ['conv1d_2[0][0]']
#  g1D)
#
#  lstm_1 (LSTM)               (None, 1, 32)                6272      ['lstm[0][0]']
#
#  flatten (Flatten)           (None, 3008)                 0         ['max_pooling1d_2[0][0]']
#
#  lstm_2 (LSTM)               (None, 64)                   24832     ['lstm_1[0][0]']
#
#  dropout_1 (Dropout)         (None, 3008)                 0         ['flatten[0][0]']
#
#  dropout (Dropout)           (None, 64)                   0         ['lstm_2[0][0]']
#
#  dense (Dense)               (None, 64)                   192576    ['dropout_1[0][0]']
#
#  concatenate (Concatenate)   (None, 128)                  0         ['dropout[0][0]',
#                                                                      'dense[0][0]']
#
#  dense_1 (Dense)             (None, 32)                   4128      ['concatenate[0][0]']
#
#  dense_2 (Dense)             (None, 2)                    66        ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 462210 (1.76 MB)
# Trainable params: 462114 (1.76 MB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
# Plot the model architecture
plot_model(model_cnn_lstm, to_file='/content/drive/MyDrive/Dataset/Outputs/model_cnn_lstm.png', show_shapes=True, show_layer_names=True)

# %%
#model_cnn_lstm.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
'''model_cnn_lstm.fit((X_train, y_train, 32),
                           validation_data=(X_val, y_val),
                           epochs=20,
                           steps_per_epoch=X_train.shape[1]//32,
                           verbose=1)'''

epochs = 100
batch_size = 32
EarlyStopping=keras.callbacks.EarlyStopping(verbose=1, patience=20, monitor="val_sparse_categorical_accuracy", mode="max",restore_best_weights=True)

model_cnn_lstm.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"]
)
history = model_cnn_lstm.fit(
    X_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[EarlyStopping],
    #validation_split=0.2
    validation_data=(X_val,y_val)
)
# Out:
# Epoch 1/100
# 60/60 [==============================] - 13s 31ms/step - loss: 0.0067 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0058 - val_sparse_categorical_accuracy: 0.9988
# Epoch 2/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0303 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.1702 - val_sparse_categorical_accuracy: 0.9607
# Epoch 3/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0134 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0129 - val_sparse_categorical_accuracy: 0.9975
# Epoch 4/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0117 - val_sparse_categorical_accuracy: 0.9975
# Epoch 5/100
# 60/60 [==============================] - 1s 14ms/step - loss: 0.0010 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0080 - val_sparse_categorical_accuracy: 0.9975
# Epoch 6/100
# 60/60 [==============================] - 1s 13ms/step - loss: 1.8356e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0100 - val_sparse_categorical_accuracy: 0.9975
# Epoch 7/100
# 60/60 [==============================] - 1s 12ms/step - loss: 8.4418e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0112 - val_sparse_categorical_accuracy: 0.9975
# Epoch 8/100
# 60/60 [==============================] - 1s 11ms/step - loss: 2.1993e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9975
# Epoch 9/100
# 60/60 [==============================] - 1s 15ms/step - loss: 7.9187e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0113 - val_sparse_categorical_accuracy: 0.9975
# Epoch 10/100
# 60/60 [==============================] - 1s 17ms/step - loss: 4.9304e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0109 - val_sparse_categorical_accuracy: 0.9975
# Epoch 11/100
# 60/60 [==============================] - 1s 19ms/step - loss: 3.9557e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0116 - val_sparse_categorical_accuracy: 0.9975
# Epoch 12/100
# 60/60 [==============================] - 1s 20ms/step - loss: 2.7796e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0122 - val_sparse_categorical_accuracy: 0.9975
# Epoch 13/100
# 60/60 [==============================] - 1s 12ms/step - loss: 2.2838e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0130 - val_sparse_categorical_accuracy: 0.9975
# Epoch 14/100
# 60/60 [==============================] - 1s 12ms/step - loss: 1.2088e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0135 - val_sparse_categorical_accuracy: 0.9975
# Epoch 15/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0054 - sparse_categorical_accuracy: 0.9979 - val_loss: 0.0277 - val_sparse_categorical_accuracy: 0.9963
# Epoch 16/100
# 60/60 [==============================] - 1s 11ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0152 - val_sparse_categorical_accuracy: 0.9963
# Epoch 17/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.0455 - val_sparse_categorical_accuracy: 0.9890
# Epoch 18/100
# 60/60 [==============================] - 1s 12ms/step - loss: 0.0020 - sparse_categorical_accuracy: 0.9989 - val_loss: 0.0235 - val_sparse_categorical_accuracy: 0.9939
# Epoch 19/100
# 60/60 [==============================] - 1s 11ms/step - loss: 9.3750e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0202 - val_sparse_categorical_accuracy: 0.9939
# Epoch 20/100
# 60/60 [==============================] - 1s 11ms/step - loss: 7.1508e-04 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0148 - val_sparse_categorical_accuracy: 0.9975
# Epoch 21/100
# 60/60 [==============================] - ETA: 0s - loss: 3.7695e-04 - sparse_categorical_accuracy: 1.0000Restoring model weights from the end of the best epoch: 1.
# 60/60 [==============================] - 1s 18ms/step - loss: 3.7695e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0141 - val_sparse_categorical_accuracy: 0.9963
# Epoch 21: early stopping

# %%
metric = "loss"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
# Get the predicted class indices using model.predict and np.argmax
y_pred_indices = np.argmax(model_cnn_lstm.predict(x_test), axis=1)

# Get the class names from the y_train dataset
class_names=['Non-exoplanet','Exoplanet']

# Generate and print the classification report
print(classification_report(y_test, y_pred_indices, target_names=class_names))
# Out:
# 18/18 [==============================] - 2s 14ms/step
#                precision    recall  f1-score   support
#
# Non-exoplanet       0.99      1.00      0.99       565
#     Exoplanet       0.00      0.00      0.00         5
#
#      accuracy                           0.99       570
#     macro avg       0.50      0.50      0.50       570
#  weighted avg       0.98      0.99      0.99       570

# %%
y_pred = model_cnn_lstm.predict(x=X_test)
# Out:
# 18/18 [==============================] - 1s 4ms/step

# %%
non_idx = np.where(y_test[:,0] == 0.)[0]
yes_idx = np.where(y_test[:,0] == 1.)[0]
plt.plot([y_pred[i] for i in yes_idx], 'bo', label='Positive Class Predictions')
plt.xlabel('Sample Index')
plt.ylabel('Predicted Value')
plt.show()
plt.plot([y_pred[i] for i in non_idx], 'ro', label='Negative Class Predictions')
plt.show()

# %%
#ROC Area under curve
y_true = (y_test[:, 0] + 0.5).astype("int")
fpr, tpr, thresholds = roc_curve(y_true, y_pred)
plt.plot(thresholds, 1.-fpr)
plt.plot(thresholds, tpr)
plt.show()
crossover_index = np.min(np.where(1.-fpr <= tpr))
crossover_cutoff = thresholds[crossover_index]
crossover_specificity = 1.-fpr[crossover_index]
print("Crossover at {0:.2f} with specificity {1:.2f}".format(crossover_cutoff, crossover_specificity))
plt.plot(fpr, tpr)
plt.show()
print("ROC area under curve is {0:.2f}".format(roc_auc_score(y_true, y_pred)))
# Out:
# Crossover at 1.00 with specificity 1.00
# ROC area under curve is 1.00

# %%
predthr = np.where(y_pred > 0.5, 1, 0)
print(classification_report(y_test, predthr))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.98      0.99       565
#          1.0       0.33      1.00      0.50         5
#
#     accuracy                           0.98       570
#    macro avg       0.67      0.99      0.75       570
# weighted avg       0.99      0.98      0.99       570

# %%
print(confusion_matrix(y_test, predthr))
# Out:
# [[555  10]
#  [  0   5]]
