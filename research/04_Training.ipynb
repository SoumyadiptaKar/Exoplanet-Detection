# %%
# %pwd
# Out:
# 'c:\\Users\\Soumyadipta\\Desktop\\Exoplanet-Detection\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Soumyadipta\\Desktop\\Exoplanet-Detection'

# %%
# Entity
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path
    updated_base_model_path: Path
    training_data: Path
    params_epochs: int
    params_batch_size: int
    params_is_augmentation: bool
    params_image_size: list



@dataclass(frozen=True)
class PrepareCallbacksConfig:
    root_dir: Path
    tensorboard_root_log_dir: Path
    checkpoint_model_filepath: Path

# %%
from exoplanetDetection.constants import *
from exoplanetDetection.utils.common import read_yaml, create_directories
import tensorflow as tf

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])
    
    def get_prepare_callback_config(self) -> PrepareCallbacksConfig:
        config = self.config.prepare_callbacks
        model_ckpt_dir = os.path.dirname(config.checkpoint_model_filepath)
        create_directories([
            Path(model_ckpt_dir),
            Path(config.tensorboard_root_log_dir)
        ])

        prepare_callback_config = PrepareCallbacksConfig(
            root_dir=Path(config.root_dir),
            tensorboard_root_log_dir=Path(config.tensorboard_root_log_dir),
            checkpoint_model_filepath=Path(config.checkpoint_model_filepath)
        )

        return prepare_callback_config


    def get_training_config(self) -> TrainingConfig:
        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params
        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "")
        create_directories([
            Path(training.root_dir)
        ])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_is_augmentation=params.AUGMENTATION,
            params_image_size=params.IMAGE_SIZE
        )

        return training_config

# %%
import time

# %%
class PrepareCallback:
    def __init__(self, config: PrepareCallbacksConfig):
        self.config = config

    
    @property
    def _create_tb_callbacks(self):
        timestamp = time.strftime("%Y-%m-%d-%H-%M-%S")
        tb_running_log_dir = os.path.join(
            self.config.tensorboard_root_log_dir,
            f"tb_logs_at_{timestamp}",
        )
        return tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)
    

    @property
    def _create_ckpt_callbacks(self):
        return tf.keras.callbacks.ModelCheckpoint(
            filepath=str(self.config.checkpoint_model_filepath),
            save_best_only=True
        )


    def get_tb_ckpt_callbacks(self):
        return [
            self._create_tb_callbacks,
            self._create_ckpt_callbacks
        ]

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
import time

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config
    
    def get_base_model(self):
        self.model = tf.keras.models.load_model(
            self.config.updated_base_model_path
        )
    
    def train_valid_generator(self):

        datagenerator_kwargs = dict(
            rescale = 1./255,
            validation_split=0.20
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )

        if self.config.params_is_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )
        else:
            train_datagenerator = valid_datagenerator

        self.train_generator = train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )

    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)


    def train(self, callback_list: list):
        self.steps_per_epoch = self.train_generator.samples // self.train_generator.batch_size
        self.validation_steps = self.valid_generator.samples // self.valid_generator.batch_size

        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_steps=self.validation_steps,
            validation_data=self.valid_generator,
            callbacks=callback_list
        )

        self.save_model(
            path=str(self.config.trained_model_path),
            model=self.model
        )

# %%
try:
    config = ConfigurationManager()
    prepare_callbacks_config = config.get_prepare_callback_config()
    prepare_callbacks = PrepareCallback(config=prepare_callbacks_config)
    callback_list = prepare_callbacks.get_tb_ckpt_callbacks()

    training_config = config.get_training_config()
    training = Training(config=training_config)
    training.get_base_model()
    training.train_valid_generator()
    training.train(
        callback_list=callback_list
    )
    
except Exception as e:
    raise e
# Out:
# [2024-03-18 11:23:11,956: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2024-03-18 11:23:11,960: INFO: common: yaml file: params.yaml loaded successfully]
# [2024-03-18 11:23:11,965: INFO: common: created directory at: artifacts]
# [2024-03-18 11:23:11,967: INFO: common: created directory at: artifacts\prepare_callbacks\checkpoint_dir]
# [2024-03-18 11:23:11,969: INFO: common: created directory at: artifacts\prepare_callbacks\tensorboard_log_dir]
# [2024-03-18 11:23:11,972: INFO: common: created directory at: artifacts\training]
# Found 222 images belonging to 2 classes.
# Found 888 images belonging to 2 classes.
# Epoch 1/100
# c:\Users\Soumyadipta\.conda\envs\exoplanet\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 92s 1s/step - accuracy: 0.5554 - loss: 1.0269 - val_accuracy: 0.6731 - val_loss: 0.6077
# Epoch 2/100
#  1/55 ━━━━━━━━━━━━━━━━━━━━ 1:01 1s/step - accuracy: 0.6875 - loss: 0.5780
# c:\Users\Soumyadipta\.conda\envs\exoplanet\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6875 - loss: 0.2943 - val_accuracy: 0.6429 - val_loss: 0.2498
# Epoch 3/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.6636 - loss: 0.6253 - val_accuracy: 0.7692 - val_loss: 0.5077
# Epoch 4/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8125 - loss: 0.2167 - val_accuracy: 0.6429 - val_loss: 0.3219
# Epoch 5/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.6956 - loss: 0.5991 - val_accuracy: 0.7692 - val_loss: 0.5106
# Epoch 6/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7500 - loss: 0.2259 - val_accuracy: 0.5000 - val_loss: 0.3192
# Epoch 7/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 71s 1s/step - accuracy: 0.7051 - loss: 0.5702 - val_accuracy: 0.7885 - val_loss: 0.4937
# Epoch 8/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.6250 - loss: 0.2936 - val_accuracy: 0.5714 - val_loss: 0.2899
# Epoch 9/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7173 - loss: 0.5632 - val_accuracy: 0.8413 - val_loss: 0.4380
# Epoch 10/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8750 - loss: 0.2186 - val_accuracy: 0.7143 - val_loss: 0.2420
# Epoch 11/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7665 - loss: 0.5164 - val_accuracy: 0.6010 - val_loss: 0.7789
# Epoch 12/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.8125 - loss: 0.2396 - val_accuracy: 0.9286 - val_loss: 0.1194
# Epoch 13/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.7566 - loss: 0.5174 - val_accuracy: 0.6442 - val_loss: 0.6751
# Epoch 14/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.2407 - val_accuracy: 0.9286 - val_loss: 0.2115
# Epoch 15/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8049 - loss: 0.4676 - val_accuracy: 0.8365 - val_loss: 0.3739
# Epoch 16/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.1039 - val_accuracy: 0.9286 - val_loss: 0.1587
# Epoch 17/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8221 - loss: 0.4105 - val_accuracy: 0.8269 - val_loss: 0.3848
# Epoch 18/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7500 - loss: 0.2707 - val_accuracy: 0.6429 - val_loss: 0.3290
# Epoch 19/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.8329 - loss: 0.3899 - val_accuracy: 0.8654 - val_loss: 0.3711
# Epoch 20/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8750 - loss: 0.1732 - val_accuracy: 0.7857 - val_loss: 0.2206
# Epoch 21/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8587 - loss: 0.3278 - val_accuracy: 0.8269 - val_loss: 0.3997
# Epoch 22/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7500 - loss: 0.2008 - val_accuracy: 1.0000 - val_loss: 0.0618
# Epoch 23/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8131 - loss: 0.4398 - val_accuracy: 0.8365 - val_loss: 0.3826
# Epoch 24/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8125 - loss: 0.2040 - val_accuracy: 0.8571 - val_loss: 0.1814
# Epoch 25/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8139 - loss: 0.3844 - val_accuracy: 0.8606 - val_loss: 0.3636
# Epoch 26/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8750 - loss: 0.1644 - val_accuracy: 0.9286 - val_loss: 0.0779
# Epoch 27/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8288 - loss: 0.3843 - val_accuracy: 0.8654 - val_loss: 0.3457
# Epoch 28/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7500 - loss: 0.3105 - val_accuracy: 0.7143 - val_loss: 0.2797
# Epoch 29/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8566 - loss: 0.3537 - val_accuracy: 0.8654 - val_loss: 0.3240
# Epoch 30/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0347 - val_accuracy: 0.8571 - val_loss: 0.1929
# Epoch 31/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8364 - loss: 0.3772 - val_accuracy: 0.8702 - val_loss: 0.3048
# Epoch 32/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8125 - loss: 0.2346 - val_accuracy: 0.9286 - val_loss: 0.1118
# Epoch 33/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8481 - loss: 0.3170 - val_accuracy: 0.8654 - val_loss: 0.3397
# Epoch 34/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 0.0217 - val_accuracy: 0.8571 - val_loss: 0.2602
# Epoch 35/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.8900 - loss: 0.3052 - val_accuracy: 0.8365 - val_loss: 0.4480
# Epoch 36/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.
100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9375 - loss: 0.0653 - val_accuracy: 0.9286 - val_loss: 0.1377
# Epoch 69/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9286 - loss: 0.1782 - val_accuracy: 0.9087 - val_loss: 0.2887
# Epoch 70/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9375 - loss: 0.0619 - val_accuracy: 0.8571 - val_loss: 0.1046
# Epoch 71/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9310 - loss: 0.1823 - val_accuracy: 0.9231 - val_loss: 0.1914
# Epoch 72/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - accuracy: 0.8125 - loss: 0.1292 - val_accuracy: 0.9286 - val_loss: 0.0519
# Epoch 73/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9223 - loss: 0.2005 - val_accuracy: 0.9279 - val_loss: 0.2030
# Epoch 74/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 1.0000 - loss: 0.0595 - val_accuracy: 1.0000 - val_loss: 0.0240
# Epoch 75/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9102 - loss: 0.2186 - val_accuracy: 0.8894 - val_loss: 0.3586
# Epoch 76/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.7143 - val_loss: 0.2676
# Epoch 77/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 102s 2s/step - accuracy: 0.9260 - loss: 0.1782 - val_accuracy: 0.9375 - val_loss: 0.2167
# Epoch 78/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.8750 - loss: 0.1404 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 79/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.9164 - loss: 0.2282 - val_accuracy: 0.9327 - val_loss: 0.2024
# Epoch 80/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9375 - loss: 0.1328 - val_accuracy: 0.9286 - val_loss: 0.0614
# Epoch 81/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.9342 - loss: 0.1955 - val_accuracy: 0.9327 - val_loss: 0.2312
# Epoch 82/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8125 - loss: 0.2363 - val_accuracy: 0.9286 - val_loss: 0.0549
# Epoch 83/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9304 - loss: 0.1787 - val_accuracy: 0.9135 - val_loss: 0.2081
# Epoch 84/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9375 - loss: 0.0658 - val_accuracy: 0.9286 - val_loss: 0.1078
# Epoch 85/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9431 - loss: 0.1643 - val_accuracy: 0.8413 - val_loss: 0.4774
# Epoch 86/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9375 - loss: 0.0362 - val_accuracy: 0.7857 - val_loss: 0.3475
# Epoch 87/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9412 - loss: 0.1488 - val_accuracy: 0.9327 - val_loss: 0.1918
# Epoch 88/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9375 - loss: 0.0650 - val_accuracy: 0.9286 - val_loss: 0.1290
# Epoch 89/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9536 - loss: 0.1215 - val_accuracy: 0.9231 - val_loss: 0.2120
# Epoch 90/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8750 - loss: 0.0877 - val_accuracy: 0.9286 - val_loss: 0.0913
# Epoch 91/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9389 - loss: 0.1570 - val_accuracy: 0.9279 - val_loss: 0.2221
# Epoch 92/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 0.0254 - val_accuracy: 0.9286 - val_loss: 0.0656
# Epoch 93/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9408 - loss: 0.1570 - val_accuracy: 0.9279 - val_loss: 0.2819
# Epoch 94/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0284
# Epoch 95/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9419 - loss: 0.1681 - val_accuracy: 0.9279 - val_loss: 0.2209
# Epoch 96/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 0.0457 - val_accuracy: 0.9286 - val_loss: 0.0522
# Epoch 97/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9559 - loss: 0.1277 - val_accuracy: 0.8990 - val_loss: 0.2809
# Epoch 98/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9375 - loss: 0.0878 - val_accuracy: 0.8571 - val_loss: 0.0977
# Epoch 99/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 69s 1s/step - accuracy: 0.9367 - loss: 0.1905 - val_accuracy: 0.9327 - val_loss: 0.1948
# Epoch 100/100
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 1.0000 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 0.0156
